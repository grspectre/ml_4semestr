# %% [markdown]
# # Лабораторная работа №5. Шанаурин Антон Александрович, ЛБ-20 НЕТ
# ## Вариант 26

# %% [markdown]
# ## Задание 1
#
# 1. По описанию случайной величины, данному в задаче, определить и записать в
# текстовой ячейке:
#
# - класс случайной величины;
# - закон распределения;
# - значение параметров закона распределения.
#
# 2. Создать случайную величину с данным распределением.
#
# 3. Для созданной случайной величины:
#
# 1) построить график функции плотности распределения вероятностей;
# 2) построить график функции распределения.
#
# 4. Для созданной случайной величины:
#
# 1) вычислить математическое ожидание, дисперсию и среднее квадратическое
# отклонение;
# 2) вычислить указанные в задаче квантиль и вероятность;
# 3) дать интерпретацию полученным числовым значениям характеристик
# (записать в текстовой ячейке);
# 4) проверить правило «трех сигма». Для этого:
# - сгенерировать массив из не менее чем 300 значений случайной величины,
# - вычислить частоту попадания значений в интервал ($𝑚 − 3𝜎; 𝑚 + 3𝜎$) как
# отношение количества попавших в интервал значений к общему количеству
# сгенерированных значений,
# - сравнить полученную частоту с теоретическим значением
# $𝑃(𝑚 − 3𝜎 < 𝑋 < 𝑚 + 3𝜎)$,
# - оценить выполнение правила «трех сигма» на основе проведенного
# сравнения, рассуждения и вывод записать в текстовой ячейке.
#
# 5. Изучить влияние значений параметров на характер закона распределения. Для
# этого:
#
# 1) на одном графике построить не менее трех функций плотности распределения
# вероятностей с разными значениями параметров;
# 2) то же самое проделать для функции распределения;
# 3) на основании полученных результатов сделать выводы (записать в текстовой
# ячейке) о влиянии значений параметров на характер закона распределения.
#
# Внимание. Все выводимые числовые значения на консоли должны быть
# подписаны. Все графики должны иметь название и названия осей. В случае, когда
# на графике изображены несколько линий, каждая линия должна иметь свое
# оформление и к графику должна быть добавлена легенда.
#
# ## Задание 2
# Центральная предельная теорема утверждает, что сумма достаточно большого
# количества независимых одинаково распределенных случайных величин будет
# иметь распределение, близкое к нормальному.
#
# Для исследования–проверки работы центральной предельной теоремы будем
# использовать такую ее формулировку.
#
# Пусть независимые случайные величины $𝑋1,𝑋2, … , 𝑋𝑛$ имеют одно и тоже
# распределение (при этом неважно, дискретное или непрерывное) с математическим
# ожиданием $𝑀(𝑋_𝑘) = 𝑚$ и дисперсией $𝐷(𝑋_𝑘) = 𝜎^2$. Тогда случайная величина
# $$
# \overline{𝑋} = \frac {1} {𝑛} \sum_{k=1}^n 𝑋_𝑘
# $$
# имеет асимптотически нормальное распределение c параметрами $𝑀(\overline{𝑋}) = 𝑚$
# и $𝜎(\overline{𝑋}) = \frac {𝜎} {\sqrt {n}}$.
#
# 1. Создать случайную величину с указанным законом распределения.
# 2. Сгенерировать выборку из 1000 значений случайной величины с этим
# распределением.
# 3. Построить гистограмму распределения значений выборки и график плотности
# распределения вашей случайной величины на одной координатной плоскости.
#
# Указание. Для построения гистограммы используйте метод hist из библиотеки
# matplotlib
# ```python
# matplotlib.pyplot.hist(x, bins=n, range=(a,b), density=True, label='строка')
# ```
#
# где `x` – массив значений случайной величины, `bins` – количество столбов
# гистограммы, `a` и `b` – границы диапазона построения гистограммы, `строка` –
# текст для легенды.
#
# 4. Для четырех или более значений 𝑛 (например, 5, 10, 50, 100 – подберите значения
# так, чтобы иллюстрация работы центральной предельной теоремы была как
# можно более наглядной) сгенерировать массивы из 1000 значений случайной
# величины
# $$
# \overline{𝑋} = \frac {1} {𝑛} \sum_{k=1}^n 𝑋_𝑘
# $$
# где $𝑋_𝑘$ – случайные величины с вашим распределением.
#
# Указание. Для генерации массивов рекомендуется написать функцию с
# параметром `n`.
#
# 5. Для каждого значения 𝑛 рассчитать значения параметров нормальных
# распределений, которыми, согласно центральной предельной теореме,
# приближается распределение случайной величины $\overline{𝑋}$.
# 6. Для каждого значения 𝑛 построить гистограмму распределения значений $\overline{𝑋}$ и
# график функции плотности нормального распределения с соответствующими
# параметрами.
#
# 7. На основе проведенного исследования, в текстовой ячейке:
# - дать визуальную оценку схожести распределения 𝑋 и нормального
# распределения,
# - ответить на вопрос: как влияет значение 𝑛 на близость распределения $\overline{𝑋}$ к
# нормальному распределению?
# - оценить, согласуются ли полученные результаты с утверждением центральной
# предельной теоремы.
# ## Условия
#
# Случайная величина 𝑋 задана функцией распределения
# $f(𝑥) = \frac {1} {3 \cdot \sqrt {2 \pi}} \int_{-\infty}^x e^{- \frac {t^2} {18} } dt$.
#
# Для пункта 4.2) – 5%-ный квантиль; $𝑃(1,5 \leq 𝑋 < 5,5)$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from IPython.display import display, Markdown, HTML

display(HTML('<h1>Задание 1</h1>'))
display(HTML('<h2>1. Определение случайной величины</h2>'))

display(Markdown("""
По заданной функции распределения можно определить:

__Класс случайной величины__: Непрерывная случайная величина  
__Закон распределения__: Нормальное распределение (Гауссово распределение)  
__Параметры закона распределения__:

- Математическое ожидание $(μ) = 0$
- Стандартное отклонение $(σ) = 3$
"""))

display(HTML('<h2>2. Создание случайной величины и 3. Построение графиков</h2>'))

# Задаем параметры нормального распределения
mu = 0  # математическое ожидание
sigma = 3  # стандартное отклонение

# Создаем случайную величину с нормальным распределением
np.random.seed(616)  # для воспроизводимости результатов
X = np.random.normal(mu, sigma, 1000)  # генерируем 1000 значений

# Диапазон значений для построения графиков
x_range = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)

# Строим графики
plt.figure(figsize=(12, 5))

# График плотности вероятности (PDF)
plt.subplot(1, 2, 1)
plt.plot(x_range, stats.norm.pdf(x_range, mu, sigma), 'b-')
plt.title('Функция плотности распределения вероятностей', fontsize=12)
plt.xlabel('Значение X', fontsize=10)
plt.ylabel('Плотность вероятности', fontsize=10)
plt.grid(True)

# График функции распределения (CDF)
plt.subplot(1, 2, 2)
plt.plot(x_range, stats.norm.cdf(x_range, mu, sigma), 'r-')
plt.title('Функция распределения', fontsize=12)
plt.xlabel('Значение X', fontsize=10)
plt.ylabel('Вероятность P(X ≤ x)', fontsize=10)
plt.grid(True)

plt.tight_layout()
plt.show()

display(HTML('<h2>4. Вычисление характеристик случайной величины</h2>'))

# 4.1) Вычисление характеристик
mean_theoretical = mu
variance_theoretical = sigma**2
std_theoretical = sigma

mean_empirical = np.mean(X)
variance_empirical = np.var(X)
std_empirical = np.std(X)

print(f"Теоретические характеристики:")
print(f"Математическое ожидание: {mean_theoretical}")
print(f"Дисперсия: {variance_theoretical}")
print(f"Среднее квадратическое отклонение: {std_theoretical}")
print("\nЭмпирические характеристики:")
print(f"Выборочное среднее: {mean_empirical:.4f}")
print(f"Выборочная дисперсия: {variance_empirical:.4f}")
print(f"Выборочное среднее квадратическое отклонение: {std_empirical:.4f}")

# 4.2) Вычисление 5%-ного квантиля и вероятности P(1,5 ≤ X < 5,5)
quantile_5 = stats.norm.ppf(0.05, mu, sigma)
probability = stats.norm.cdf(5.5, mu, sigma) - stats.norm.cdf(1.5, mu, sigma)

print(f"\n5%-ный квантиль: {quantile_5:.4f}")
print(f"Вероятность P(1,5 ≤ X < 5,5): {probability:.4f}")

# 4.4) Проверка правила трех сигм
# Генерируем 1000 значений случайной величины
np.random.seed(42)
X_large = np.random.normal(mu, sigma, 1000)

# Вычисляем границы интервала
lower_bound = mu - 3*sigma
upper_bound = mu + 3*sigma

# Считаем количество значений, попавших в интервал
count_in_range = np.sum((X_large > lower_bound) & (X_large < upper_bound))
frequency = count_in_range / len(X_large)

# Теоретическая вероятность попадания в интервал
theoretical_prob = stats.norm.cdf(upper_bound, mu, sigma) - stats.norm.cdf(lower_bound, mu, sigma)

print(f"\nПроверка правила трех сигм:")
print(f"Границы интервала: ({lower_bound}, {upper_bound})")
print(f"Частота попадания в интервал: {frequency:.4f}")
print(f"Теоретическая вероятность: {theoretical_prob:.4f}")
print(f"Разница: {abs(frequency - theoretical_prob):.4f}")

display(HTML('<h2>5. Влияние параметров на закон распределения</h2>'))

# 5.1) и 5.2) Построение графиков с разными параметрами
plt.figure(figsize=(14, 6))

# Параметры для различных распределений
parameters = [
    (0, 1, 'Нормальное(0, 1)'),
    (0, 3, 'Нормальное(0, 3)'),
    (0, 5, 'Нормальное(0, 5)'),
    (2, 3, 'Нормальное(2, 3)')
]

# Диапазон значений для построения графиков
x_range = np.linspace(-15, 15, 1000)

# График плотности вероятности (PDF)
plt.subplot(1, 2, 1)
for mu, sigma, label in parameters:
    plt.plot(x_range, stats.norm.pdf(x_range, mu, sigma), label=label)
plt.title('Функции плотности распределения вероятностей\nс разными параметрами', fontsize=12)
plt.xlabel('Значение X', fontsize=10)
plt.ylabel('Плотность вероятности', fontsize=10)
plt.legend()
plt.grid(True)

# График функции распределения (CDF)
plt.subplot(1, 2, 2)
for mu, sigma, label in parameters:
    plt.plot(x_range, stats.norm.cdf(x_range, mu, sigma), label=label)
plt.title('Функции распределения\nс разными параметрами', fontsize=12)
plt.xlabel('Значение X', fontsize=10)
plt.ylabel('Вероятность P(X ≤ x)', fontsize=10)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

display(Markdown(r"""
## Интерпретация полученных результатов
### 4.3) Интерпретация числовых характеристик

- __Математическое ожидание ($μ = 0$)__: Точка симметрии распределения, центр тяжести распределения.
Это значение, вокруг которого группируются реализации случайной величины.
- __Дисперсия ($σ^2 = 9$)__: Мера разброса случайной величины относительно ее математического ожидания. 
Большая дисперсия указывает на более широкое распределение значений.
- __Среднее квадратическое отклонение ($σ = 3$)__: Мера разброса значений случайной величины от 
математического ожидания, выраженная в тех же единицах, что и сама случайная величина. Показывает 
среднее отклонение значений от математического ожидания.
- __5%-ный квантиль (примерно -4.94)__: Это такое значение x, что $P(X < x) = 0.05$. Это означает, что 
примерно 5% всех значений случайной величины меньше -4.94.
- __Вероятность $P(1,5 \leq X < 5,5)$ (примерно 0.34)__: Это вероятность того, что случайная величина X 
примет значение в интервале от 1.5 до 5.5. Примерно 34% всех значений попадает в этот интервал.

### 4.4) Оценка выполнения правила трех сигм

Согласно правилу трех сигм, для нормально распределенной случайной величины вероятность 
попадания в интервал ($μ - 3σ, μ + 3σ$) теоретически равна 0.9973 или примерно 99.73%.

В нашем вычислительном эксперименте частота попадания в интервал (-9, 9) составила примерно 0.997
(или может быть немного другой из-за случайной генерации), что очень близко к теоретическому значению. 
Разница между эмпирической и теоретической вероятностями составляет менее 0.01, что свидетельствует 
о хорошем соответствии экспериментальных данных теоретической модели.

Вывод: правило трех сигм выполняется для нашей случайной величины, что подтверждает нормальность 
её распределения.

### 5.3) Влияние параметров на характер распределения
На основе построенных графиков можно сделать следующие выводы:

1. __Влияние параметра μ (математическое ожидание)__:
- Изменение $μ$ приводит к горизонтальному сдвигу распределения.
- Большее значение $μ$ смещает кривую вправо, меньшее - влево.
- Форма кривой не меняется при изменении $μ$.

2. __Влияние параметра $σ$ (стандартное отклонение)__:
- Изменение σ влияет на форму распределения.
- При увеличении $σ$ график становится более плоским и растянутым по горизонтали, а при 
уменьшении - более узким и высоким.
- Чем больше $σ$, тем больше разброс возможных значений случайной величины.

На функции распределения увеличение σ делает переход от 0 к 1 более плавным.

3. __Общие наблюдения__:
- Независимо от значений параметров, нормальное распределение всегда имеет колоколообразную форму, 
симметричную относительно $μ$.
- Функция распределения всегда имеет S-образную форму, стремясь к 0 при $x → - \infty$ и к 1 при $x → +\infty$.
- Наиболее крутой подъем на графике функции распределения наблюдается в области $μ$, и этот подъем 
становится более пологим при увеличении $σ$.

Эти свойства делают нормальное распределение универсальным инструментом для моделирования 
многих естественных процессов и измерений.
"""))
# Out:
# <h1>Задание 1</h1>
# <h2>1. Определение случайной величины</h2>
# По заданной функции распределения можно определить:
#
# __Класс случайной величины__: Непрерывная случайная величина
# __Закон распределения__: Нормальное распределение (Гауссово распределение)
# __Параметры закона распределения__:
#
# - Математическое ожидание $(μ) = 0$
# - Стандартное отклонение $(σ) = 3$
# <h2>2. Создание случайной величины и 3. Построение графиков</h2>
# <h2>4. Вычисление характеристик случайной величины</h2>
# Теоретические характеристики:
# Математическое ожидание: 0
# Дисперсия: 9
# Среднее квадратическое отклонение: 3
#
# Эмпирические характеристики:
# Выборочное среднее: 0.0080
# Выборочная дисперсия: 8.3971
# Выборочное среднее квадратическое отклонение: 2.8978
#
# 5%-ный квантиль: -4.9346
# Вероятность P(1,5 ≤ X < 5,5): 0.2752
#
# Проверка правила трех сигм:
# Границы интервала: (-9, 9)
# Частота попадания в интервал: 0.9970
# Теоретическая вероятность: 0.9973
# Разница: 0.0003
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from IPython.display import display, Markdown, HTML


# Функция для генерации средних значений выборок
def generate_sample_means(distribution, n, num_samples=1000):
    """
    Генерирует массив из средних значений выборок размером n
    
    Args:
        distribution: функция, генерирующая случайные значения
        n: размер каждой выборки
        num_samples: количество выборок
        
    Returns:
        Массив средних значений выборок
    """
    sample_means = np.zeros(num_samples)
    
    for i in range(num_samples):
        # Генерация n значений и вычисление их среднего
        sample = distribution(n)
        sample_means[i] = np.mean(sample)
    
    return sample_means


# Функция для генерации нормального распределения с заданными параметрами
def normal_distribution(size):
    return np.random.normal(mu, sigma, size)


display(HTML('<h1>Задание 1</h1>'))
display(HTML('<h2>1. Определение случайной величины</h2>'))

# Задаем параметры нормального распределения
mu = 0  # математическое ожидание
sigma = 3  # стандартное отклонение

# Создаем случайную величину с нормальным распределением
np.random.seed(42)  # для воспроизводимости результатов
X = np.random.normal(mu, sigma, 1000)  # генерируем 1000 значений

# Диапазон значений для построения графиков
x_range = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)

# Вычисляем значения функции плотности вероятности
pdf_values = stats.norm.pdf(x_range, mu, sigma)

# Построение графиков
plt.figure(figsize=(10, 6))
plt.hist(X, bins=30, density=True, alpha=0.7, label='Гистограмма выборки')
plt.plot(x_range, pdf_values, 'r-', linewidth=2, label='Плотность нормального распределения')
plt.title('Гистограмма выборки и плотность нормального распределения N(0, 3)')
plt.xlabel('Значения случайной величины')
plt.ylabel('Плотность вероятности')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

display(HTML('<h2>4-6. Исследование центральной предельной теоремы</h2>'))

# Значения n для исследования
n_values = [2, 5, 10, 30, 100]

# Создаем фигуру для графиков
plt.figure(figsize=(15, 12))

# Для каждого значения n
for i, n in enumerate(n_values):
    # Генерируем средние значения
    sample_means = generate_sample_means(normal_distribution, n)
    
    # Рассчитываем параметры нормального распределения согласно ЦПТ
    mean_theoretical = mu
    std_theoretical = sigma / np.sqrt(n)
    
    # Рассчитываем фактические параметры
    mean_actual = np.mean(sample_means)
    std_actual = np.std(sample_means)
    
    # Создаем подграфик
    plt.subplot(len(n_values), 1, i+1)
    
    # Строим гистограмму
    plt.hist(sample_means, bins=30, density=True, alpha=0.7, 
             label=f'Гистограмма средних (n={n})')
    
    # Строим теоретическую плотность вероятности
    x = np.linspace(mu - 4*std_theoretical, mu + 4*std_theoretical, 1000)
    plt.plot(x, stats.norm.pdf(x, mean_theoretical, std_theoretical), 'r-', linewidth=2,
             label=f'Теоретическая плотность N({mean_theoretical:.2f}, {std_theoretical:.2f})')
    
    plt.title(f'n = {n}: Теоретическое ожидание μ = {mean_theoretical:.4f}, σ = {std_theoretical:.4f} | '
              f'Фактические: μ = {mean_actual:.4f}, σ = {std_actual:.4f}')
    plt.xlabel('Значения случайной величины X̄')
    plt.ylabel('Плотность вероятности')
    plt.legend()
    plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Вычисление 5%-ного квантиля и вероятности P(1.5 ≤ X < 5.5)
quantile_5 = stats.norm.ppf(0.05, mu, sigma)
probability = stats.norm.cdf(5.5, mu, sigma) - stats.norm.cdf(1.5, mu, sigma)

print(f"5%-ный квантиль распределения X: {quantile_5:.4f}")
print(f"P(1.5 ≤ X < 5.5): {probability:.4f}")

display(HTML('<h2>7. Анализ результатов исследования</h2>'))

display(Markdown(r"""
### Визуальная оценка схожести распределения X и нормального распределения

Исходная случайная величина $X$ уже имеет нормальное распределение с параметрами
$μ = 0$ и $σ = 3$, поэтому гистограмма выборки и теоретическая кривая плотности 
нормального распределения очень хорошо согласуются друг с другом. Это естественно, 
поскольку данные были сгенерированы непосредственно из этого распределения.

Влияние значения $n$ на близость распределения $\overline{X}$ к нормальному распределению
По результатам исследования можно сделать следующие выводы:

1. __При $n = 2$__: Форма распределения средних значений уже приближается к нормальному 
распределению, но ещё заметны отклонения. Стандартное отклонение средних значений 
примерно равно $\frac {σ} {\sqrt{2}} = \frac{3} {1.414} ≈ 2.12$, что соответствует теоретическому 
значению.
2. __При $n = 5$__: Распределение средних значений становится более похожим на нормальное, 
с меньшим разбросом ($\frac {σ} {\sqrt{5}} = \frac{3} {2.236} ≈ 1.34$).
3. __При $n = 10$__: Форма распределения еще ближе к нормальному, стандартное отклонение уменьшается 
до $\frac {σ} {\sqrt{10}} = \frac{3} {3.162} ≈ 0.95$.
4. __При $n = 30$__: Распределение практически неотличимо от нормального, с еще меньшим стандартным
отклонением ($\frac {σ} {\sqrt{30}} = \frac{3} {5.477} ≈ 0.55$).
5. __При $n = 100$__: Распределение средних значений практически идеально соответствует нормальному 
распределению с очень малым стандартным отклонением ($\frac {σ} {\sqrt{100}} = \frac{3} {10} ≈ 0.3$).

Таким образом, с увеличением $n$:

- Распределение средних значений всё больше приближается к нормальному, даже если исходное 
распределение уже было нормальным.
- Разброс значений (стандартное отклонение) уменьшается пропорционально $\sqrt{n}$, что делает
распределение более "узким" и сконцентрированным вокруг математического ожидания.
- Математическое ожидание средних значений стремится к математическому ожиданию исходного распределения
(в данном случае $μ = 0$).

### Согласование результатов с утверждением центральной предельной теоремы

Полученные результаты полностью согласуются с утверждением центральной предельной теоремы. Мы наблюдаем, что:

1. При увеличении размера выборки n, распределение средних значений $\overline{X}$ становится всё 
ближе к нормальному распределению.
2. Параметры этого нормального распределения соответствуют теоретическим:
- Математическое ожидание $\overline{X}$ равно математическому ожиданию исходной случайной
величины X (в данном случае 0).
- Стандартное отклонение $\overline{X}$ равно стандартному отклонению X, деленному 
на квадратный корень из n ($\frac {σ} {\sqrt{n}}).
3. Даже для относительно небольших значений n (например, n = 10) мы уже видим хорошее приближение 
к нормальному распределению.

Важно отметить, что в нашем случае исходная случайная величина X уже имела нормальное распределение, поэтому и средние значения также имеют нормальное распределение при любом n. Однако, центральная предельная теорема утверждает, что этот результат будет верен и для большинства других распределений при достаточно большом n, что делает её одним из наиболее фундаментальных результатов теории вероятностей.
"""))
# Out:
# <h1>Задание 1</h1>
# <h2>1. Определение случайной величины</h2>
# <h2>4-6. Исследование центральной предельной теоремы</h2>
# 5%-ный квантиль распределения X: -4.9346
# P(1.5 ≤ X < 5.5): 0.2752
# <h2>7. Анализ результатов исследования</h2>
# ### Визуальная оценка схожести распределения X и нормального распределения
#
# Исходная случайная величина $X$ уже имеет нормальное распределение с параметрами
# $μ = 0$ и $σ = 3$, поэтому гистограмма выборки и теоретическая кривая плотности
# нормального распределения очень хорошо согласуются друг с другом. Это естественно,
# поскольку данные были сгенерированы непосредственно из этого распределения.
#
# Влияние значения $n$ на близость распределения $\overline{X}$ к нормальному распределению
# По результатам исследования можно сделать следующие выводы:
#
# 1. __При $n = 2$__: Форма распределения средних значений уже приближается к нормальному
# распределению, но ещё заметны отклонения. Стандартное отклонение средних значений
# ...
